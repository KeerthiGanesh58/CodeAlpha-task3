# %%
import pandas as pd
from textblob import TextBlob
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('amazon_product_reviews.csv')

# %%
print("Sample data:")
print(df.head())
# Out:
# Sample data:
#                                               review
# 0  The product is decent, but I expected more fea...
# 1  The product is decent, but I expected more fea...
# 2  Worst purchase ever. Would not recommend this ...
# 3  Perfect for my needs! It's simple, efficient, ...
# 4  Very disappointed. It doesn't match the descri...

# %%
def get_sentiment(review):
    analysis = TextBlob(review)
    polarity = analysis.sentiment.polarity

    if polarity > 0.1:
        return 'Positive'
    elif polarity < -0.1:
        return 'Negative'
    else:
        return 'Neutral'

# %%
df['sentiment'] = df['review'].apply(get_sentiment)

# %%
print("\nData with Sentiment Predictions:")
print(df.head())
# Out:
# Data with Sentiment Predictions:
#                                               review sentiment
# 0  The product is decent, but I expected more fea...  Positive
# 1  The product is decent, but I expected more fea...  Positive
# 2  Worst purchase ever. Would not recommend this ...  Negative
# 3  Perfect for my needs! It's simple, efficient, ...  Positive
# 4  Very disappointed. It doesn't match the descri...  Negative

# %%
sentiment_counts = df['sentiment'].value_counts()
print("\nSentiment Counts:")
print(sentiment_counts)
# Out:
# Sentiment Counts:
# sentiment
# Positive    222
# Negative    150
# Neutral     128
# Name: count, dtype: int64

# %%
sentiment_counts = df['sentiment'].value_counts()
print("\nSentiment Counts:")
print(sentiment_counts)
# Out:
# Sentiment Counts:
# sentiment
# Positive    222
# Negative    150
# Neutral     128
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8, 5))
colors = ['green', 'blue', 'red']
sentiment_counts.plot(kind='bar', color=colors)
plt.title('Sentiment Distribution of Reviews')
plt.xlabel('Sentiment')
plt.ylabel('Number of Reviews')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
